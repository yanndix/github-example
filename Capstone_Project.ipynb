# %% [markdown]
# # Capstone Project

# %% [markdown]
# ### This project will be mainly about submitting python code for my capstone project

# %%
import numpy as np
import pandas as pd

# %%
print("Hello Capstone Project Course!")
# Out:
# Hello Capstone Project Course!
